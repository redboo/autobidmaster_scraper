# %%
import requests

# %%
headers = {
 "Accept": "application/json, text/plain, */*",
 "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36" 
}

# %% [markdown]
# Получить количество автомобилей "Run & Drive Verified"

# %%
reqUrl = "https://www.autobidmaster.com/ru/data/v2/inventory/search/filters?custom_search=featured-run_and_drive"

payload = ""

response = requests.request("GET", reqUrl, data=payload,  headers=headers)

print(response.text)
# Out:
# {"total":105771,"filters":{"location-state":{"values":{"all":[{"key":"AB","label":"Alberta","cnt":154,"selected":false,"stateSlug":"alberta","countrySlug":"canada"},{"key":"AK","label":"Alaska","cnt":146,"selected":false,"stateSlug":"alaska","countrySlug":"usa"},{"key":"AL","label":"Alabama","cnt":3082,"selected":false,"stateSlug":"alabama","countrySlug":"usa"},{"key":"AR","label":"Arkansas","cnt":1543,"selected":false,"stateSlug":"arkansas","countrySlug":"usa"},{"key":"AZ","label":"Arizona","cnt":1044,"selected":false,"stateSlug":"arizona","countrySlug":"usa"},{"key":"CA","label":"California","cnt":6414,"selected":false,"stateSlug":"california","countrySlug":"usa"},{"key":"CO","label":"Colorado","cnt":6063,"selected":false,"stateSlug":"colorado","countrySlug":"usa"},{"key":"CT","label":"Connecticut","cnt":1150,"selected":false,"stateSlug":"connecticut","countrySlug":"usa"},{"key":"DE","label":"Delaware","cnt":735,"selected":false,"stateSlug":"delaware","countrySlug":"usa"},{"key":"F
# ...
